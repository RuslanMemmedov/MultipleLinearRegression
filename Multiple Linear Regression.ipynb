# %% [markdown]
# # Coffee Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('coffee.csv')

# %%
data
# Out:
#                                                   title  \
# 0       folgers classic roast ground coffee, 40.3-ounce
# 1     café bustelo, espresso style dark roast ground...
# 2     folgers classic roast ground coffee, medium ro...
# 3     maxwell house original roast ground coffee, 42...
# 4     great value classic roast medium ground coffee...
# ...                                                 ...
# 1395  xhao reusable capsules easy to clean easy to u...
# 1396  cafe yaucono espresso dark roast ground coffee...
# 1397  starbucks dark roast coffee with 2x caffeine, ...
# 1398  starbucks holiday blend, medium roast k-cup co...
# 1399  super coffee vanilla latte iced coffee bottle,...
#
#                      coffee_type  rating  reviews  \
# 0                  classic roast     3.8       93
# 1            espresso,dark roast     4.7      914
# 2     medium roast,classic roast     4.4      740
# 3                            NaN     4.8     1321
# ...

# %%
data.describe(include='all')
# Out:
#                                                     title   coffee_type  \
# count                                                1400          1121
# unique                                                973           120
# top     folgers black silk ground coffee, smooth dark ...  medium roast
# freq                                                   32           313
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#              rating       reviews  seller_name  \
# count   1400.000000   1400.000000         1400
# ...

# %%
data.dtypes
# Out:
# title                          object
# coffee_type                    object
# rating                        float64
# reviews                         int64
# seller_name                    object
# thumbnail                      object
# price                         float64
# weight                         object
# weight_formatted_to_gramms    float64
# dtype: object

# %%
data.columns
# Out:
# Index(['title', 'coffee_type', 'rating', 'reviews', 'seller_name', 'thumbnail',
#        'price', 'weight', 'weight_formatted_to_gramms'],
#       dtype='object')

# %%
data = data[['rating', 'reviews','weight_formatted_to_gramms','price']]

# %%
data
# Out:
#       rating  reviews  weight_formatted_to_gramms  price
# 0        3.8       93                      1142.5  13.92
# 1        4.7      914                       283.5   3.76
# 2        4.4      740                       734.3   9.97
# 3        4.8     1321                      1204.9   9.92
# 4        4.7     1598                      1360.8   9.98
# ...      ...      ...                         ...    ...
# 1395     0.0        0                       272.2  13.89
# 1396     0.0        0                       249.5  10.99
# 1397     4.3     5036                       340.2  12.98
# 1398     4.5      397                       623.7  17.72
# 1399     4.3     2791                       623.7   2.98
#
# [1400 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# rating                        0
# reviews                       0
# weight_formatted_to_gramms    0
# price                         0
# dtype: int64

# %%
df_corr = data.corr()
df = pd.DataFrame(df_corr['price'])
df
# Out:
#                                price
# rating                     -0.075347
# reviews                     0.071503
# weight_formatted_to_gramms  0.283919
# price                       1.000000

# %%
plt.figure(figsize = (16,5))

sns.heatmap(data.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data,x=data['weight_formatted_to_gramms'])
# Out:
# <AxesSubplot:xlabel='weight_formatted_to_gramms'>

# %%
q1=data.quantile(0.25)
q3=data.quantile(0.75)
IQR=q3-q1

Lower = q1-IQR
Upper = q3+IQR

# %%
data['weight_formatted_to_gramms'] = np.where(data['weight_formatted_to_gramms'] > Upper['weight_formatted_to_gramms'],
                                  Upper['weight_formatted_to_gramms'],data['weight_formatted_to_gramms'])
# Out:
# C:\py\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.boxplot(data=data,x=data['weight_formatted_to_gramms'])
# Out:
# <AxesSubplot:xlabel='weight_formatted_to_gramms'>

# %%
x = data[['weight_formatted_to_gramms']]
y = data['price']

# %%
x_reshaped = x.values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(x_reshaped, y, test_size = 0.2, random_state=42)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = reg.predict(X_test)

# %%
data_new = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
data_new
# Out:
#       Actual  Predicted
# 665    10.32  14.354572
# 624     9.98  11.618487
# 115     7.48  14.716045
# 478    16.98  11.618487
# 233    15.72  14.199785
# ...      ...        ...
# 188    14.92  14.716045
# 1091   14.54  16.781084
# 377    14.92  14.716045
# 351    17.92  16.264824
# 415    10.24  11.618487
#
# [280 rows x 2 columns]

# %%
#For intercept:
print(reg.intercept_)

#For slope:
print(reg.coef_)
# Out:
# 8.520928530786668
# [0.00910511]

# %%
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))
mse = (mean_squared_error(y_test, y_pred))
mae = (mean_absolute_error(y_test, y_pred))
print(rmse)
print(mse)
print(mae)
# Out:
# 9.879083430373273
# 97.59628942427575
# 6.987030634007542

# %%
errors = abs(y_pred - y_test)

print('Mean Absolute Error:', round(np.mean(errors), 2))
# Out:
# Mean Absolute Error: 6.99

# %%
mape = 100 * (errors / y_test)

accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 1), '%.')
# Out:
# Accuracy: 18.2 %.

# %% [markdown]
# # Exam data

# %%
df = pd.read_csv(r'C:\Users\Nutzer\OneDrive\Desktop\DataSoCool\Data\regression\exam.csv')

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'final score'],
#       dtype='object')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.describe(include='all')
# Out:
#        gender race/ethnicity parental level of education     lunch  \
# count    1000           1000                        1000      1000
# unique      2              5                           6         2
# top      male        group C                some college  standard
# freq      517            323                         222       652
# mean      NaN            NaN                         NaN       NaN
# std       NaN            NaN                         NaN       NaN
# min       NaN            NaN                         NaN       NaN
# 25%       NaN            NaN                         NaN       NaN
# 50%       NaN            NaN                         NaN       NaN
# 75%       NaN            NaN                         NaN       NaN
# max       NaN            NaN                         NaN       NaN
#
#        test preparation course   math score  reading score  writing score  \
# count                     1000  1000.000000    1000.000000     855.000000
# ...

# %%
df.isnull().sum()
# Out:
# gender                           0
# race/ethnicity                   0
# parental level of education      0
# lunch                            0
# test preparation course          0
# math score                       0
# reading score                    0
# writing score                  145
# final score                      0
# dtype: int64

# %%
df['writing score'].fillna(value=df['writing score'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# final score                    0
# dtype: int64

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_corr = df.corr()

# %%
df_corr
# Out:
#                math score  reading score  writing score  final score
# math score       1.000000       0.819398       0.757572    -0.035257
# reading score    0.819398       1.000000       0.885148    -0.057058
# writing score    0.757572       0.885148       1.000000    -0.050135
# final score     -0.035257      -0.057058      -0.050135     1.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'final score'],
#       dtype='object')

# %%
df['parental level of education'].value_counts()
# Out:
# some college          222
# associate's degree    203
# high school           202
# some high school      191
# bachelor's degree     112
# master's degree        70
# Name: parental level of education, dtype: int64

# %%
df['lunch'].value_counts()
# Out:
# standard        652
# free/reduced    348
# Name: lunch, dtype: int64

# %%
df['test preparation course'].value_counts()
# Out:
# none         665
# completed    335
# Name: test preparation course, dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    323
# group D    262
# group B    205
# group E    131
# group A     79
# Name: race/ethnicity, dtype: int64

# %%
df['gender'] = df['gender'].map({'female': 0, 'male': 1})

# %%
df['test preparation course'] = df['test preparation course'].map({'none': 0, 'completed': 1})

# %%
df['lunch'] = df['lunch'].map({'standard': 0, 'free/reduced': 1})

# %%
df=pd.get_dummies(df, prefix=['race'], columns=['race/ethnicity'], drop_first=True)

# %%
df=pd.get_dummies(df, prefix=['education'], columns=['parental level of education'], drop_first=True)

# %%
df
# Out:
#      gender  lunch  test preparation course  math score  reading score  \
# 0         1      0                        1          67             67
# 1         0      1                        0          40             59
# 2         1      1                        0          59             60
# 3         1      0                        0          77             78
# 4         1      0                        1          78             73
# ..      ...    ...                      ...         ...            ...
# 995       1      0                        0          73             70
# 996       1      1                        1          85             91
# 997       0      1                        0          32             35
# 998       0      0                        0          73             74
# 999       1      0                        1          65             60
#
#      writing score  final score  race_group B  race_group C  race_group D  \
# ...

# %%
df.columns
# Out:
# Index(['gender', 'lunch', 'test preparation course', 'math score',
#        'reading score', 'writing score', 'final score', 'race_group B',
#        'race_group C', 'race_group D', 'race_group E',
#        'education_bachelor's degree', 'education_high school',
#        'education_master's degree', 'education_some college',
#        'education_some high school'],
#       dtype='object')

# %%
x = df[['gender', 'lunch', 'test preparation course','race_group B',
       'race_group C', 'race_group D', 'race_group E',
       "education_bachelor's degree", 'education_high school',
       "education_master's degree", 'education_some college',
       'education_some high school']]
y = df['final score']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=42)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = reg.predict(X_test)

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1
# Out:
#      Actual  Predicted
# 521      96  74.679475
# 737      64  75.888601
# 740      99  74.488934
# 660      77  77.406779
# 411      51  73.649718
# ..      ...        ...
# 408      85  79.425986
# 332      89  75.888493
# 208      76  76.364885
# 613      87  77.610340
# 78       84  75.873399
#
# [200 rows x 2 columns]

# %%
errors = abs(y_pred - y_test)

print('Mean Absolute Error:', round(np.mean(errors), 2))
# Out:
# Mean Absolute Error: 12.46

# %%
mape = 100 * (errors / y_test)

accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 1), '%.')
# Out:
# Accuracy: 82.9 %.
